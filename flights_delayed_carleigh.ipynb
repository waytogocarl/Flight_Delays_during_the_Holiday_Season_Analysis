# %%
#set dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy import stats

# %%
# load aviation data
aviation_data = pd.read_csv("./dataset/airline_data.csv")
aviation_data.head()
# Out:
#   flight_date  year  month carrier       carrier_name airport  \
# 0     12/2023  2023     12      9E  Endeavor Air Inc.     ABE
# 1     12/2023  2023     12      9E  Endeavor Air Inc.     AEX
# 2     12/2023  2023     12      9E  Endeavor Air Inc.     AGS
# 3     12/2023  2023     12      9E  Endeavor Air Inc.     ALB
# 4     12/2023  2023     12      9E  Endeavor Air Inc.     ATL
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         72.0        5.0
# 1           Alexandria, LA: Alexandria International         62.0        7.0
# 2        Augusta, GA: Augusta Regional at Bush Field         95.0       10.0
# 3                   Albany, NY: Albany International         23.0        2.0
# 4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       2111.0      256.0
#
#    carrier_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.46  ...          0.0              0.81            0.0
# 1        4.25  ...          0.0              1.75            0.0
# 2        5.94  ...          0.0              3.00            0.0
# 3        0.56  ...          0.0              1.44            1.0
# 4       76.88  ...          0.0            117.94            1.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      672.0           61.0          574.0       20.0
# 1           0.0      348.0          252.0            0.0       33.0
# 2           0.0      859.0          536.0            0.0       47.0
# 3           0.0       75.0            9.0            0.0        0.0
# 4           0.0    21424.0         8906.0          732.0     1487.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 17.0
# 1             0.0                 63.0
# 2             0.0                276.0
# 3             0.0                 66.0
# 4             0.0              10299.0
#
# [5 rows x 22 columns]

# %%
print(aviation_data["flight_date"].unique())
# Out:
# ['12/2023' '11/2023' '10/2023' '9/2023' '8/2023' '7/2023' '6/2023'
#  '5/2023' '4/2023' '3/2023' '2/2023' '1/2023' '12/2022' '11/2022'
#  '10/2022' '9/2022' '8/2022' '7/2022' '6/2022' '5/2022' '4/2022' '3/2022'
#  '2/2022' '1/2022' '12/2021' '11/2021']

# %%
flights = aviation_data.to_dict(orient='records')

filtered_flights = []

for flight in flights:
    flight_date = flight["flight_date"]
    if flight_date.startswith("11") or flight_date.startswith("12"):
        filtered_flights.append(flight)

# %%
formatted_flights = []

random_flights = random.sample(filtered_flights, min(200, len(filtered_flights)))

for flight in random_flights:
    airline_name = flight["carrier_name"]
    departure_airport = flight["airport_name"]  # Remove the brackets to access the value
    departure_date = flight["flight_date"]  # Remove the brackets to access the value
    airline_delay = flight["carrier_delay"]  # Remove the brackets to access the value
    weather_delay = flight["weather_delay"]  # Remove the brackets to access the value
    nas_delay = flight["nas_delay"]  # Remove the brackets to access the value
    security_delay = flight["security_delay"]  # Remove the brackets to access the value
    late_aircraft_delay = flight["late_aircraft_delay"]  # Remove the brackets to access the value
    count_airline_delay = flight["carrier_ct"]  # Remove the brackets to access the value
    count_weather_delay = flight["weather_ct"]  # Remove the brackets to access the value
    count_nas_delay = flight["nas_ct"]  # Remove the brackets to access the value
    count_security_delay = flight["security_ct"]  # Remove the brackets to access the value
    count_late_aircraft_delay = flight["late_aircraft_ct"]  # Remove the brackets to access the value

    # NAS is the National Aviation System
    formatted_flights.append({
        "Airline Name": airline_name,
        "Departure Airport": departure_airport,
        "Departure Date": departure_date,
        "Delay due to Airline": airline_delay,
        "Delay due to Weather": weather_delay,
        "Delay due to NAS": nas_delay,
        "Delay due to Security": security_delay,
        "Delay due to Late Aircraft": late_aircraft_delay,
        "# of Airline Delays": count_airline_delay,
        "# of Weather Delays": count_weather_delay,
        "# of NAS Delays": count_nas_delay,
        "# of Security Delays": count_security_delay,
        "# of Late Aircraft Delays": count_late_aircraft_delay
    })

# %%
flight_data_df = pd.DataFrame(formatted_flights)

print(flight_data_df)
# Out:
#                                 Airline Name  \
# 0                      SkyWest Airlines Inc.
# 1                    Delta Air Lines Network
# 2                            Spirit Airlines
# 3                                  Envoy Air
# 4                      SkyWest Airlines Inc.
# ..                                       ...
# 195                              Horizon Air
# 196                    SkyWest Airlines Inc.
# 197            CommuteAir LLC dba CommuteAir
# 198  GoJet Airlines LLC d/b/a United Express
# 199                          JetBlue Airways
#
#                                      Departure Airport Departure Date  \
# 0             Pittsburgh, PA: Pittsburgh International        12/2021
# 1       Grand Rapids, MI: Gerald R. Ford International        12/2022
# 2                 Richmond, VA: Richmond International        11/2023
# 3             Des Moines, IA: Des Moines International        12/2021
# 4            Kalispell, MT: Glacier Park International        11/2022
# ..                                                 ...            ...
# 195   Sun Valley/Hailey/Ketchum, ID: Friedman Memorial        11/2022
# 196      Madison, WI: Dane County Regional-Truax Field        12/2023
# 197  Birmingham, AL: Birmingham-Shuttlesworth Inter...        12/2022
# 198                 Memphis, TN: Memphis International        12/2021
# 199           Pittsburgh, PA: Pittsburgh International        11/2022
#
#      Delay due to Airline  Delay due to Weather  Delay due to NAS  \
# 0                  2354.0                1046.0              29.0
# 1                  2231.0                  25.0             356.0
# 2                   364.0                   0.0             359.0
# 3                   138.0                 114.0             324.0
# 4                   607.0                  52.0               0.0
# ..                    ...                   ...               ...
# 195                   0.0                   0.0               0.0
# 196                1178.0                   0.0             132.0
# 197                1135.0                   0.0             224.0
# 198                   0.0                   0.0               0.0
# 199                1364.0                   0.0              81.0
#
#      Delay due to Security  Delay due to Late Aircraft  # of Airline Delays  \
# 0                      0.0                       355.0                32.00
# 1                      0.0                       355.0                29.34
# 2                     14.0                       162.0                 6.88
# 3                      0.0                       121.0                 2.29
# 4                      0.0                       390.0                14.00
# ..                     ...                         ...                  ...
# 195                    0.0                         0.0                 0.00
# 196                    0.0                       462.0                10.35
# 197                    0.0                       372.0                12.52
# 198                    0.0                         0.0                 0.00
# 199                    0.0                       396.0                17.57
#
#      # of Weather Delays  # of NAS Delays  # of Security Delays  \
# 0                  12.00             1.00                  0.00
# 1                   0.49             9.15                  0.00
# 2                   0.00             4.45                  0.88
# 3                   1.62             8.39                  0.00
# 4                   2.00             0.00                  0.00
# ..                   ...              ...                   ...
# 195                 0.00             0.00                  0.00
# 196                 0.00             4.79                  0.00
# 197                 0.00             9.00                  0.00
# 198                 0.00             0.00                  0.00
# 199                 0.00             2.85                  0.00
#
#      # of Late Aircraft Delays
# 0                         5.00
# 1                         9.02
# 2                         5.80
# 3                         3.70
# 4                         5.00
# ..                         ...
# 195                       0.00
# 196                       4.85
# 197                       4.48
# 198                       0.00
# 199                       7.58
#
# [200 rows x 13 columns]

# %%
flight_data_df.to_csv("flights.csv", index=True, mode='w')

flight_data_df = pd.read_csv("flights.csv", index_col=0)

flight_data_df.head()

# %%
#import json
#import requests

#aviation_stack_api = "c612023093ef04f3142c66defcf82a7a"
#base_url = "https://api.aviationstack.com/v1/flights"

#date_from = "2018-11-01"
#date_to = "2023-12-31"

#url = f"{base_url}?access_key={aviation_stack_api}&flight_date={date_from},{date_to}"

#response = requests.get(url)
#data = response.json()

#print(data)

# %%
#flights = data.get('data', [])

#filtered_flights = []

#for flight in flights:
    #flight_date = pd.to_datetime(flight["flight_date"]).date()
    #if (flight_date.year >= 2018 and flight_date.year <= 2023) and (flight_date.month in [11, 12]):
        #filtered_flights.append(flight)

#formatted_flights = []

#random_flights = random.sample(filtered_flights, min(200, len(filtered_flights)))

#for flight in random_flights:
    #flight_number = flight["flight"]["number"]
    #flight_date = flight["flight_date"]
    #airline_name = flight["airline"]["name"]
    #scheduled_departure = flight["departure"]["scheduled"]
    #estimated_departure = flight["departure"]["estimated"]
    #actual_departure = flight["departure"]["actual"]
    #dep_iata = flight["departure"]["iata"]
    #arr_iata = flight["arrival"]["iata"]
    #flight_status = flight["flight_status"]

    #formatted_flights.append({"Flight Number": flight_number,
                        #"Date": flight_date,
                        #"Airline": airline_name,
                        #"Scheduled Departure": scheduled_departure,
                        #"Estimated Departure": estimated_departure,
                        #"Actual Departure": actual_departure,
                        #"Departure Location": dep_iata,
                        #"Arrival Location": arr_iata,
                        #"Flight Status": flight_status})
